# %%
import os
import pandas as pd
import numpy as np

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df = pd.read_csv("C:/Users/sushm/OneDrive/Desktop/Digital-Wellbeing-Analytics/data/raw/smartphone_usage.csv")
print("Dataset loaded successfully!")
print("Shape:", df.shape)
# Out:
# Dataset loaded successfully!
# Shape: (7500, 16)

# %%
df_clean = df.copy()

print("Backup copy created.")
# Out:
# Backup copy created.

# %%
duplicate_count = df_clean.duplicated().sum()

print("Number of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 0

# %%
df_clean = df_clean.drop_duplicates()

print("Shape after removing duplicates:", df_clean.shape)
# Out:
# Shape after removing duplicates: (7500, 16)

# %%
missing_values = df_clean.isnull().sum()

print(missing_values)
# Out:
# transaction_id               0
# user_id                      0
# age                          0
# gender                       0
# daily_screen_time_hours      0
# social_media_hours           0
# gaming_hours                 0
# work_study_hours             0
# sleep_hours                  0
# notifications_per_day        0
# app_opens_per_day            0
# weekend_screen_time          0
# stress_level                 0
# academic_work_impact         0
# addiction_level            819
# addicted_label               0
# dtype: int64

# %%
print(df_clean["addicted_label"].value_counts())
# Out:
# addicted_label
# 1    5308
# 0    2192
# Name: count, dtype: int64

# %%
print(df_clean["addicted_label"].value_counts(normalize=True) * 100)
# Out:
# addicted_label
# 1    70.773333
# 0    29.226667
# Name: proportion, dtype: float64

# %%
print("Gender:")
print(df_clean["gender"].value_counts())

print("\nStress Level:")
print(df_clean["stress_level"].value_counts())

print("\nAcademic/Work Impact:")
print(df_clean["academic_work_impact"].value_counts())

print("\nAddiction Level:")
print(df_clean["addiction_level"].value_counts(dropna=False))
# Out:
# Gender:
# gender
# Male      2553
# Other     2486
# Female    2461
# Name: count, dtype: int64
#
# Stress Level:
# stress_level
# High      2560
# Low       2503
# Medium    2437
# Name: count, dtype: int64
#
# Academic/Work Impact:
# academic_work_impact
# No     3753
# Yes    3747
# Name: count, dtype: int64
#
# Addiction Level:
# addiction_level
# Moderate    2874
# Severe      2434
# Mild        1373
# NaN          819
# Name: count, dtype: int64

# %%
print(df_clean.dtypes)
# Out:
# transaction_id              object
# user_id                     object
# age                          int64
# gender                      object
# daily_screen_time_hours    float64
# social_media_hours         float64
# gaming_hours               float64
# work_study_hours           float64
# sleep_hours                float64
# notifications_per_day        int64
# app_opens_per_day            int64
# weekend_screen_time        float64
# stress_level                object
# academic_work_impact        object
# addiction_level             object
# addicted_label               int64
# dtype: object

# %%
print("Age range:")
print(df_clean["age"].min(), "to", df_clean["age"].max())

print("\nDaily screen time range:")
print(
    df_clean["daily_screen_time_hours"].min(),
    "to",
    df_clean["daily_screen_time_hours"].max()
)

print("\nSocial media hours range:")
print(
    df_clean["social_media_hours"].min(),
    "to",
    df_clean["social_media_hours"].max()
)

print("\nGaming hours range:")
print(
    df_clean["gaming_hours"].min(),
    "to",
    df_clean["gaming_hours"].max()
)

print("\nWork/study hours range:")
print(
    df_clean["work_study_hours"].min(),
    "to",
    df_clean["work_study_hours"].max()
)

print("\nSleep hours range:")
print(
    df_clean["sleep_hours"].min(),
    "to",
    df_clean["sleep_hours"].max()
)

print("\nNotifications per day range:")
print(
    df_clean["notifications_per_day"].min(),
    "to",
    df_clean["notifications_per_day"].max()
)

print("\nApp opens per day range:")
print(
    df_clean["app_opens_per_day"].min(),
    "to",
    df_clean["app_opens_per_day"].max()
)

print("\nWeekend screen time range:")
print(
    df_clean["weekend_screen_time"].min(),
    "to",
    df_clean["weekend_screen_time"].max()
)
# Out:
# Age range:
# 18 to 35
#
# Daily screen time range:
# 3.0 to 12.0
#
# Social media hours range:
# 0.5 to 6.0
#
# Gaming hours range:
# 0.0 to 4.0
#
# Work/study hours range:
# 0.5 to 6.0
#
# Sleep hours range:
# 4.5 to 9.0
#
# Notifications per day range:
# 20 to 250
#
# App opens per day range:
# 15 to 180
#
# Weekend screen time range:
# 3.58 to 14.88

# %%
# Create a clean copy of the dataset
df_clean = df.copy()

# Remove duplicate rows
df_clean = df_clean.drop_duplicates()

# Reset the index after cleaning
df_clean = df_clean.reset_index(drop=True)

# Display the final shape
print("Cleaned dataset shape:", df_clean.shape)

# Check missing values
print("\nMissing values:")
print(df_clean.isnull().sum())
# Out:
# Cleaned dataset shape: (7500, 16)
#
# Missing values:
# transaction_id               0
# user_id                      0
# age                          0
# gender                       0
# daily_screen_time_hours      0
# social_media_hours           0
# gaming_hours                 0
# work_study_hours             0
# sleep_hours                  0
# notifications_per_day        0
# app_opens_per_day            0
# weekend_screen_time          0
# stress_level                 0
# academic_work_impact         0
# addiction_level            819
# addicted_label               0
# dtype: int64

# %%
df_clean.dtypes
# Out:
# transaction_id              object
# user_id                     object
# age                          int64
# gender                      object
# daily_screen_time_hours    float64
# social_media_hours         float64
# gaming_hours               float64
# work_study_hours           float64
# sleep_hours                float64
# notifications_per_day        int64
# app_opens_per_day            int64
# weekend_screen_time        float64
# stress_level                object
# academic_work_impact        object
# addiction_level             object
# addicted_label               int64
# dtype: object

# %%
os.makedirs("data/processed", exist_ok=True)
df_clean.to_csv("data/processed/smartphone_usage_cleaned.csv", index=False)

# %%
print(df_clean.shape)
# Out:
# (7500, 16)

# %%
import os

print("Jupyter is currently working in:")
print(os.getcwd())
# Out:
# Jupyter is currently working in:
# C:\Users\sushm

# %%
import os

print("Does data folder exist here?", os.path.exists("data"))
print("Folders/files here:")
print(os.listdir())
# Out:
# Does data folder exist here? True
# Folders/files here:
# ...

# %%
os.makedirs("data/processed", exist_ok=True)

df_clean.to_csv(
    "data/processed/smartphone_usage_cleaned.csv",
    index=False
)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!
